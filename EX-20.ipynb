# %% [markdown]
# <a href="https://colab.research.google.com/github/venky8635/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION-/blob/main/EX-20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib

def compute_hashes(data: bytes):
    return {
        "MD5": hashlib.md5(data).hexdigest(),
        "SHA1": hashlib.sha1(data).hexdigest(),
        "SHA256": hashlib.sha256(data).hexdigest(),
    }

original_data = b"hello"
tampered_data = b"Hello"


hashes_original = compute_hashes(original_data)
hashes_tampered = compute_hashes(tampered_data)
hashes_original_repeat = compute_hashes(original_data)

print("Original Data (hello):")
print(hashes_original)

print("\nTampered Data (Hello):")
print(hashes_tampered)

print("\nRepeated Hash of Original Data:")
print(hashes_original_repeat)

print("\nConsistency Check:")
print("Original hashes match repeated hashes:", hashes_original == hashes_original_repeat)

print("Original and tampered hashes are the same:", hashes_original == hashes_tampered)
# Out:
# Original Data (hello):
# {'MD5': '5d41402abc4b2a76b9719d911017c592', 'SHA1': 'aaf4c61ddcc5e8a2dabede0f3b482cd9aea9434d', 'SHA256': '2cf24dba5fb0a30e26e83b2ac5b9e29e1b161e5c1fa7425e73043362938b9824'}
#
# Tampered Data (Hello):
# {'MD5': '8b1a9953c4611296a827abf8c47804d7', 'SHA1': 'f7ff9e8b7bb2e09b70935a5d785e0cc5d9d0abf0', 'SHA256': '185f8db32271fe25f561a6fc938b2e264306ec304eda518007d1764826381969'}
#
# Repeated Hash of Original Data:
# {'MD5': '5d41402abc4b2a76b9719d911017c592', 'SHA1': 'aaf4c61ddcc5e8a2dabede0f3b482cd9aea9434d', 'SHA256': '2cf24dba5fb0a30e26e83b2ac5b9e29e1b161e5c1fa7425e73043362938b9824'}
#
# Consistency Check:
# Original hashes match repeated hashes: True
# Original and tampered hashes are the same: False
